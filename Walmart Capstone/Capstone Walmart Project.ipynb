# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"G:\Intelipaat Rajani\Walmart DataSet.csv")
data.head(7)
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
# 5      1  12-03-2010    1439541.59             0        57.79       2.667
# 6      1  19-03-2010    1472515.79             0        54.58       2.720
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106
# 5  211.380643         8.106
# 6  211.215635         8.106

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
data.shape
# Out:
# (6435, 8)

# %%
data.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]>

# %%
data.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
plt.scatter(data.Fuel_Price,data.Weekly_Sales)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.isna().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# Store             45
# Date             143
# Weekly_Sales    6435
# Holiday_Flag       2
# Temperature     3528
# Fuel_Price       892
# CPI             2145
# Unemployment     349
# dtype: int64

# %%
data['Weekly_Sales'].nunique()
# Out:
# 6435

# %% [markdown]
# Therefore there are no null values and duplicates in the dataset.
#
# a. If the weekly sales are affected by the unemployment rate, if yes - which stores
# are suffering the most?

# %%
data.set_index('Date',inplace = True)
data
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 05-02-2010      1    1643690.90             0        42.31       2.572
# 12-02-2010      1    1641957.44             1        38.51       2.548
# 19-02-2010      1    1611968.17             0        39.93       2.514
# 26-02-2010      1    1409727.59             0        46.63       2.561
# 05-03-2010      1    1554806.68             0        46.50       2.625
# ...           ...           ...           ...          ...         ...
# 28-09-2012     45     713173.95             0        64.88       3.997
# 05-10-2012     45     733455.07             0        64.89       3.985
# 12-10-2012     45     734464.36             0        54.47       4.000
# 19-10-2012     45     718125.53             0        56.47       3.969
# 26-10-2012     45     760281.43             0        58.85       3.882
#
#                    CPI  Unemployment
# Date
# 05-02-2010  211.096358         8.106
# 12-02-2010  211.242170         8.106
# 19-02-2010  211.289143         8.106
# 26-02-2010  211.319643         8.106
# 05-03-2010  211.350143         8.106
# ...                ...           ...
# 28-09-2012  192.013558         8.684
# 05-10-2012  192.170412         8.667
# 12-10-2012  192.327265         8.667
# 19-10-2012  192.330854         8.667
# 26-10-2012  192.308899         8.667
#
# [6435 rows x 7 columns]

# %%
print(data['Weekly_Sales'].min())
print(data['Weekly_Sales'].max())
# Out:
# 209986.25
# 3818686.45

# %%
sub_data = data.loc[:, ['Store', 'Weekly_Sales', 'Unemployment']];sub_data
# Out:
#             Store  Weekly_Sales  Unemployment
# Date
# 05-02-2010      1    1643690.90         8.106
# 12-02-2010      1    1641957.44         8.106
# 19-02-2010      1    1611968.17         8.106
# 26-02-2010      1    1409727.59         8.106
# 05-03-2010      1    1554806.68         8.106
# ...           ...           ...           ...
# 28-09-2012     45     713173.95         8.684
# 05-10-2012     45     733455.07         8.667
# 12-10-2012     45     734464.36         8.667
# 19-10-2012     45     718125.53         8.667
# 26-10-2012     45     760281.43         8.667
#
# [6435 rows x 3 columns]

# %% [markdown]
# '''d1=data.groupby(['Store']).sum().reset_index()
# plt.figure(figsize=(15,5))
# sns.barplot(x='Store',y='Weekly_Sales', data=d1, order=d1.sort_values(by='Weekly_Sales',ascending=False)['Store'])'''

# %%
correlations = sub_data.groupby('Store').corr()

# %%
correlations = correlations.reset_index()
correlations
# Out:
#     Store       level_1  Weekly_Sales  Unemployment
# 0       1  Weekly_Sales      1.000000     -0.097955
# 1       1  Unemployment     -0.097955      1.000000
# 2       2  Weekly_Sales      1.000000      0.066325
# 3       2  Unemployment      0.066325      1.000000
# 4       3  Weekly_Sales      1.000000     -0.230413
# ..    ...           ...           ...           ...
# 85     43  Unemployment     -0.201954      1.000000
# 86     44  Weekly_Sales      1.000000     -0.780076
# 87     44  Unemployment     -0.780076      1.000000
# 88     45  Weekly_Sales      1.000000     -0.004041
# 89     45  Unemployment     -0.004041      1.000000
#
# [90 rows x 4 columns]

# %%
correlations.drop(['level_1', 'Weekly_Sales'], axis = 1, inplace=True)
correlations.head()
# Out:
#    Store  Unemployment
# 0      1     -0.097955
# 1      1      1.000000
# 2      2      0.066325
# 3      2      1.000000
# 4      3     -0.230413

# %%
correlations.set_index(['Store'], inplace=True)
correlations.head()
# Out:
#        Unemployment
# Store
# 1         -0.097955
# 1          1.000000
# 2          0.066325
# 2          1.000000
# 3         -0.230413

# %%
correlations.rename({'Unemployment':'Weekly_Sales vs Unemployment correlation'}, inplace = True, axis = 1)
correlations.head(8)
# Out:
#        Weekly_Sales vs Unemployment correlation
# Store
# 1                                     -0.097955
# 1                                      1.000000
# 2                                      0.066325
# 2                                      1.000000
# 3                                     -0.230413
# 3                                      1.000000
# 4                                     -0.337015
# 4                                      1.000000

# %%
correlations[(correlations['Weekly_Sales vs Unemployment correlation'] <= -0.4)]
# Out:
#        Weekly_Sales vs Unemployment correlation
# Store
# 38                                    -0.785290
# 44                                    -0.780076

# %% [markdown]
# Stores 38 and 44 are affected most by unemployment.

# %% [markdown]
# b. If the weekly sales show a seasonal trend, when and what could be the reason?

# %%
import seaborn as sns
figure = plt.figure(figsize=(10,4))
plot = sns.lineplot(data=data, x = data.index, y = 'Weekly_Sales',label='weekly sales')
plt.show()

# %% [markdown]
# c. Does temperature affect the weekly sales in any manner?

# %%
plt.scatter(data['Weekly_Sales'], data['Temperature'])
plt.xlabel('Weekly Sales')
plt.ylabel('Temperature')
plt.title('Scatter Plot of Weekly Sales vs. Temperature')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=data, x = "Temperature", y = 'Weekly_Sales',label='weekly sales')
plt.show()

# %% [markdown]
# Temperature does not afffect the sales of the store.

# %% [markdown]
# d. How is the Consumer Price index affecting the weekly sales of various stores?

# %%
figure = plt.figure(figsize=(12,7))
sns.scatterplot(data = data, x = 'CPI', y = 'Weekly_Sales',hue='Store')
plt.show()

# %% [markdown]
# CPI also does not affects the sales.

# %% [markdown]
# e. Top performing stores according to the historical data.

# %%
performance = data.groupby('Store')['Weekly_Sales'].mean().sort_values(ascending=False)
top = performance.nlargest(5)
top
# Out:
# Store
# 20    2.107677e+06
# 4     2.094713e+06
# 14    2.020978e+06
# 13    2.003620e+06
# 2     1.925751e+06
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# store 20 is the top performer.

# %% [markdown]
# f. The worst performing store, and how significant is the difference between the
# highest and lowest performing stores.

# %%
worst = performance.nsmallest(3)
worst
# Out:
# Store
# 33    259861.692028
# 44    302748.866014
# 5     318011.810490
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# The worst performing store is 33.

# %%
top-worst
# Out:
# Store
# 2    NaN
# 4    NaN
# 5    NaN
# 13   NaN
# 14   NaN
# 20   NaN
# 33   NaN
# 44   NaN
# Name: Weekly_Sales, dtype: float64

# %%
performance.iloc[0]-performance.iloc[-1]
# Out:
# 1847815.1783216782

# %% [markdown]
# The difference in sales is around 18L . It is a big difference.

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(data['Weekly_Sales'])
print(f'p-value: {result[1]}')
# Out:
# p-value: 0.00011655869699901207

# %%
date_range = pd.date_range(start=data.index.min(), end=data.index.max(), freq='W-FRI')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18292\1123379105.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   date_range = pd.date_range(start=data.index.min(), end=data.index.max(), freq='W-FRI')

# %%
'''
data['Weekly_Sales'] = pd.to_datetime(data['Weekly_Sales'])  #converting month column str to datetime
data.index = data['Weekly_Sales'] #making month column as a index column
del data['Weekly_Sales']
'''
# Out:
# "\ndata['Weekly_Sales'] = pd.to_datetime(data['Weekly_Sales'])  #converting month column str to datetime\ndata.index = data['Weekly_Sales'] #making month column as a index column\ndel data['Weekly_Sales']\n"

# %%
'''

#seasonal Decompose
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_result = seasonal_decompose(data['Weekly_Sales'].dropna(),freq='W-Fri')
decompose_result.plot();
#can't understand what is the error..tried different things too many

'''
# Out:
# "\n\n#seasonal Decompose\nfrom statsmodels.tsa.seasonal import seasonal_decompose\ndecompose_result = seasonal_decompose(data['Weekly_Sales'].dropna(),freq='W-Fri')\ndecompose_result.plot();\n#can't understand what is the error..tried different things too many\n\n"

# %%
def P(pr):
    from statsmodels.tsa.stattools import adfuller
    result = adfuller(pr)
    print(f'p-value: {result[1]}')

# %%
def acf_plot(fc):
    '''Plots an Autocorrelation Function for the given series'''
    from statsmodels.tsa.stattools import acf 
    from statsmodels.graphics.tsaplots import plot_acf

    acf_vals = acf(fc)
    plot_acf(acf_vals)
    plt.show()

# %%
def pacf_plot(srs,nlags):
    '''Plots an Partial Autocorrelation Function for the given series'''
    from statsmodels.tsa.stattools import pacf
    from statsmodels.graphics.tsaplots import plot_pacf

    pacf_vals = pacf(srs)
    while True:
        try:
            plot_pacf(pacf_vals, lags = nlags)
            break
        except:
            plt.close('all')
            nlags -= 1

# %% [markdown]
# Store 1 model

# %%
s1 = data[data['Store'] == 1].loc[:,'Weekly_Sales']
s1 = pd.DataFrame(s1)
s1
# Out:
#             Weekly_Sales
# Date
# 05-02-2010    1643690.90
# 12-02-2010    1641957.44
# 19-02-2010    1611968.17
# 26-02-2010    1409727.59
# 05-03-2010    1554806.68
# ...                  ...
# 28-09-2012    1437059.26
# 05-10-2012    1670785.97
# 12-10-2012    1573072.81
# 19-10-2012    1508068.77
# 26-10-2012    1493659.74
#
# [143 rows x 1 columns]

# %%
s1.index.freq = 'W-FRI'
s1.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#seasonal Decompose
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_result = seasonal_decompose(data['s1'].dropna(),period=7)
decompose_result.plot();

# %%
s1['logx'] = np.log(s1['Weekly_Sales'])
s1['ma'] = s1['logx'].rolling(window=12).mean()
s1.dropna(inplace=True)
s1['dif'] = s1['logx'] - s1['ma']

# %%
s1['dif2'] = s1['dif'].diff()
s1.dropna(inplace=True)

# %%
P(s1['dif2'])
# Out:
# p-value: 6.331252088801247e-08

# %%
acf_plot(s1['dif2'])

# %%
pacf_plot(s1['dif2'], 10)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
train = s1['dif2'].iloc[:120]
test = s1['dif2'].iloc[120:]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model1 = SARIMAX(train, order = (0,1,0), seasonal_order=(0,1,0,12))
fm1 = model1.fit()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
s1preds = fm1.predict(start = len(train),
                   end = len(train) + len(test) - 1,
                   dynamic = True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
s1['dif2'].plot()
s1preds.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s1fcast = fm1.forecast(steps = 36)
s1['dif2'].plot()
s1fcast.plot()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# <Axes: xlabel='Date'>

# %%
s1fcast
# Out:
# 120   -0.030207
# 121    0.034633
# 122    0.031471
# 123   -0.057756
# 124   -0.070069
# 125    0.014301
# 126    0.120156
# 127   -0.159245
# 128   -0.032209
# 129   -0.038311
# 130    0.112847
# 131   -0.035211
# 132   -0.041572
# 133    0.023268
# 134    0.020106
# 135   -0.069121
# 136   -0.081434
# 137    0.002936
# 138    0.108791
# 139   -0.170611
# 140   -0.043575
# 141   -0.049676
# 142    0.101482
# 143   -0.046576
# 144   -0.052937
# 145    0.011903
# 146    0.008740
# 147   -0.080486
# 148   -0.092800
# 149   -0.008429
# 150    0.097426
# 151   -0.181976
# 152   -0.054940
# 153   -0.061041
# 154    0.090116
# 155   -0.057941
# Name: predicted_mean, dtype: float64

# %% [markdown]
# Store 2 MODEL

# %%
s2 = data[data['Store'] == 2].loc[:,'Weekly_Sales']
s2 = pd.DataFrame(s2)
s2
# Out:
#             Weekly_Sales
# Date
# 05-02-2010    2136989.46
# 12-02-2010    2137809.50
# 19-02-2010    2124451.54
# 26-02-2010    1865097.27
# 05-03-2010    1991013.13
# ...                  ...
# 28-09-2012    1746470.56
# 05-10-2012    1998321.04
# 12-10-2012    1900745.13
# 19-10-2012    1847990.41
# 26-10-2012    1834458.35
#
# [143 rows x 1 columns]

# %%
s2.index.freq = 'W-FRI'
s2.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s2['logx'] = np.log(s2['Weekly_Sales'])
s2['ma'] = s2['logx'].rolling(window=12).mean()
s2.dropna(inplace=True)

# %%
s2['dif'] = s2['logx'] - s2['ma']
s2['dif2'] = s2['dif'].diff()
s2.dropna(inplace=True)

# %%
P(s2['dif2'])
# Out:
# p-value: 2.8041439303003506e-07

# %%
acf_plot(s2['dif2'])

# %%
pacf_plot(s2['dif2'], 10)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
train = s2['dif2'].iloc[:120]
test = s2['dif2'].iloc[120:]

# %%
model2 = SARIMAX(train, order = (1,2,1), seasonal_order=(1,2,1,12))
fm2 = model2.fit()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
s2preds = fm2.predict(start = len(train),
                   end = len(train) + len(test) - 1,
                   dynamic = True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
s2['dif2'].plot()
s2preds.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s2fcast = fm2.forecast(steps = 36)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
s2['dif2'].plot()
s2fcast.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s2fcast
# Out:
# 120    0.041476
# 121    0.010231
# 122    0.103565
# 123   -0.036102
# 124    0.008327
# 125    0.071623
# 126    0.045831
# 127   -0.078635
# 128    0.005010
# 129    0.034251
# 130    0.104745
# 131    0.004574
# 132    0.038745
# 133    0.015480
# 134    0.121968
# 135   -0.019090
# 136    0.003079
# 137    0.066477
# 138    0.083049
# 139   -0.085871
# 140    0.015703
# 141    0.021348
# 142    0.131868
# 143   -0.004803
# 144    0.058110
# 145    0.012895
# 146    0.143090
# 147   -0.020259
# 148    0.006630
# 149    0.075635
# 150    0.084084
# 151   -0.091294
# 152    0.015410
# 153    0.023009
# 154    0.138196
# 155   -0.009029
# Name: predicted_mean, dtype: float64

# %% [markdown]
#  Store 19 MODEL

# %%
s19 = data[data['Store'] == 19].loc[:,'Weekly_Sales']
s19 = pd.DataFrame(s19)
s19
# Out:
#             Weekly_Sales
# Date
# 05-02-2010    1507637.17
# 12-02-2010    1536549.95
# 19-02-2010    1515976.11
# 26-02-2010    1373270.06
# 05-03-2010    1495844.57
# ...                  ...
# 28-09-2012    1338299.02
# 05-10-2012    1408016.10
# 12-10-2012    1352809.50
# 19-10-2012    1321102.35
# 26-10-2012    1322117.96
#
# [143 rows x 1 columns]

# %%
s19.index.freq = 'W-FRI'
s19.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s19['logx'] = np.log(s19['Weekly_Sales'])
s19['ma'] = s19['logx'].rolling(window=12).mean()
s19.dropna(inplace=True)
s19['dif'] = s19['logx'] - s19['ma']

# %%
s19['dif2'] = s19['dif'].diff()
s19.dropna(inplace=True)
P(s19['dif2'])
# Out:
# p-value: 9.933847247381862e-11

# %%
acf_plot(s19['dif2'])

# %%
pacf_plot(s19['dif2'], 10)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
train = s19['dif2'].iloc[:120]
test = s19['dif2'].iloc[120:]

# %%
model19 = SARIMAX(train, order = (2,1,0), seasonal_order=(2,1,0,12))
fm19 = model19.fit()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
s19preds = fm19.predict(start = len(train),
                   end = len(train) + len(test) - 1,
                   dynamic = True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
s19['dif2'].plot()
s19preds.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s19fcast = fm19.forecast(steps = 36)
s19['dif2'].plot()
s19fcast.plot()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# <Axes: xlabel='Date'>

# %%
s19fcast
# Out:
# 120    0.025763
# 121    0.124288
# 122    0.182218
# 123   -0.258096
# 124    0.007681
# 125    0.055646
# 126    0.050489
# 127    0.023925
# 128    0.088699
# 129    0.126318
# 130    0.059170
# 131    0.020324
# 132    0.070668
# 133    0.099728
# 134    0.081182
# 135    0.026737
# 136    0.047399
# 137    0.145204
# 138   -0.010093
# 139   -0.035734
# 140    0.081039
# 141    0.112837
# 142    0.097429
# 143    0.037952
# 144    0.110511
# 145    0.088014
# 146    0.090844
# 147    0.000419
# 148    0.067841
# 149    0.066823
# 150    0.122979
# 151   -0.039638
# 152    0.087764
# 153    0.083042
# 154    0.127528
# 155    0.088667
# Name: predicted_mean, dtype: float64

# %% [markdown]
# Store 20 MODEL

# %%
s20 = data[data['Store'] == 20].loc[:,'Weekly_Sales']
s20 = pd.DataFrame(s20)
s20
# Out:
#             Weekly_Sales
# Date
# 05-02-2010    2401395.47
# 12-02-2010    2109107.90
# 19-02-2010    2161549.76
# 26-02-2010    1898193.95
# 05-03-2010    2119213.72
# ...                  ...
# 28-09-2012    2008350.58
# 05-10-2012    2246411.89
# 12-10-2012    2162951.36
# 19-10-2012    1999363.49
# 26-10-2012    2031650.55
#
# [143 rows x 1 columns]

# %%
s20.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s20['logx'] = np.log(s20['Weekly_Sales'])
s20['ma'] = s20['logx'].rolling(window=12).mean()
s20.dropna(inplace=True)
s20['dif'] = s20['logx'] - s20['ma']
s20['dif2'] = s20['dif'].diff()
s20.dropna(inplace=True)
P(s20['dif2'])
# Out:
# p-value: 3.648308173774311e-10

# %%
acf_plot(s20['dif2'])
pacf_plot(s20['dif2'],10)

# %%
train = s20['dif2'].iloc[:120]
test = s20['dif2'].iloc[120:]
model20 = SARIMAX(train, order = (2,1,0), seasonal_order=(2,1,0,12))
fm20 = model20.fit()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
s20preds = fm20.predict(start = len(train),
                   end = len(train) + len(test) - 1,
                   dynamic = True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
s20['dif2'].plot()
print(s20preds.plot())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
s20fcast = fm20.forecast(steps = 48)
s20['dif2'].plot()
s20fcast.plot()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# <Axes: xlabel='Date'>

# %%
s20fcast
# Out:
# 120    0.061510
# 121    0.114631
# 122    0.181252
# 123   -0.231273
# 124    0.052004
# 125    0.106448
# 126    0.033404
# 127   -0.009313
# 128    0.154972
# 129    0.147379
# 130    0.068978
# 131   -0.000117
# 132    0.120923
# 133    0.105512
# 134    0.124813
# 135   -0.020410
# 136    0.082361
# 137    0.186444
# 138   -0.005726
# 139   -0.008770
# 140    0.088978
# 141    0.168201
# 142    0.110735
# 143    0.040429
# 144    0.130007
# 145    0.128179
# 146    0.160804
# 147   -0.019416
# 148    0.075943
# 149    0.148209
# 150    0.132268
# 151    0.007169
# 152    0.088009
# 153    0.136993
# 154    0.156525
# 155    0.084282
# 156    0.159389
# 157    0.180399
# 158    0.225856
# 159   -0.056827
# 160    0.130835
# 161    0.202920
# 162    0.113066
# 163    0.059752
# 164    0.185169
# 165    0.214923
# 166    0.167072
# 167    0.096853
# Name: predicted_mean, dtype: float64

# %% [raw]
# Store 4 MODEL

# %%
s4=data[data['Store']==4].loc[:,'Weekly_Sales']
s4=pd.DataFrame(s4)
s4
# Out:
#             Weekly_Sales
# Date
# 05-02-2010    2135143.87
# 12-02-2010    2188307.39
# 19-02-2010    2049860.26
# 26-02-2010    1925728.84
# 05-03-2010    1971057.44
# ...                  ...
# 28-09-2012    2027620.23
# 05-10-2012    2209835.43
# 12-10-2012    2133026.07
# 19-10-2012    2097266.85
# 26-10-2012    2149594.46
#
# [143 rows x 1 columns]

# %%
s4.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s4['logx'] = np.log(s4['Weekly_Sales'])
s4['ma'] = s4['logx'].rolling(window=12).mean()
s4.dropna(inplace=True)
s4['dif'] = s4['logx'] - s4['ma']
s4['dif2'] = s4['dif'].diff()
s4.dropna(inplace=True)
P(s4['dif2'])
# Out:
# p-value: 1.4260809528911281e-08

# %%
acf_plot(s4['dif2'])
pacf_plot(s4['dif2'],10)
train = s4['dif2'].iloc[:120]
test = s4['dif2'].iloc[120:]
model4 = SARIMAX(train, order = (2,1,0), seasonal_order=(2,1,0,12))
fm4 = model4.fit()

s4preds = fm4.predict(start = len(train),
                   end = len(train) + len(test) - 1,
                   dynamic = True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   _index = to_datetime(index)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
s4['dif2'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
s4preds.plot()
# Out:
# <Axes: >

# %%
s4fcast = fm4.forecast(steps = 36)
s4['dif2'].plot()
s4fcast.plot()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# <Axes: xlabel='Date'>

# %%
# Out:
# <Axes: >

# %%
print(s4fcast)
s4fcast.plot()
# Out:
# 120   -0.039486
# 121    0.024554
# 122    0.008437
# 123    0.015173
# 124   -0.031306
# 125   -0.006821
# 126   -0.035173
# 127    0.001488
# 128   -0.028344
# 129   -0.022577
# 130    0.027373
# 131   -0.073506
# 132   -0.043782
# 133   -0.008703
# 134   -0.004641
# 135   -0.001071
# 136   -0.013903
# 137   -0.016421
# 138   -0.044829
# 139   -0.009894
# 140   -0.024039
# 141   -0.031936
# 142   -0.010879
# 143   -0.042588
# 144   -0.062432
# 145   -0.002761
# 146   -0.033222
# 147    0.006602
# 148   -0.026972
# 149   -0.012834
# 150   -0.066262
# 151   -0.024280
# 152   -0.025092
# 153   -0.035022
# 154   -0.012585
# 155   -0.064850
# Name: predicted_mean, dtype: float64
# <Axes: >
